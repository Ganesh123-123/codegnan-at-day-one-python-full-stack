# %%
s = input()
validate_string = "qwubuyygfcbgiuhgyuubg@09"
if len(s) >= 8:
    if  s[0].isupper() or s[0].islower():
        for i in range(1, len(s)):
            if s[i] not in validate_string:
                print(f"invalid username because character {s[i]}")
                break
        else:
            print("valid string")
    else:
        print("username not valid because first chracter is not upper or lower ")
else:
    print("user is not valid because the length of the charcter is less then 8")
# Out:
#  8
# user is not valid because the length of the charcter is less then 8

# %%
for i in range(1,6):
    if i==10:
        print(i)
    else:
        print("program done")
# Out:
# program done
# program done
# program done
# program done
# program done

# %%
def add (a,b)
return a+b
def sub(a,b):
    return a-b
    def mul(a*b)
def div(a,b):
    if b==0:
        return"zero divisiopn not possible"
        return a/b
if_name_=="_main_":
print("welcom to small level caluclater")
n1= int(input("enter number 1:"))
n2=int(input("enter number 2:"))
print("1.addition/n 2. sub/n 3.mul/n 4.div")
if choice ==1:
    print("sum of two numbers:",addition(n1,n2))
elif choice ==2:
    print("sub of two numbers is:",sub(n1,n2))
elif choice ==3 
print("mul of two numbers is:",mul(n1,n2))
elif choice ==4:
print("div of two numbers is:",div(n1,n2))
else
# Out:
#   Cell In[2], line 1
#     def add (a,b)
#                  ^
# SyntaxError: expected ':'
