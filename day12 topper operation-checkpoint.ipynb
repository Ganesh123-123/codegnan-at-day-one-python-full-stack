# %%
# who is topper

print("welcome to the who is topper")
n=int(input("enter the number of students inthe class: "))
names=[]
marks=[]
total_marks=[]
percentage=[]

print("enter the all student marks")
for i in range (n):
    print(f"enter the roll number{i+1} student marks")
    name= input("enter the student name:")
    print("enter the Telugu,English,Hindi,Maths,Scince,Social marks, as per the order")
    telugu,english,hindi,maths,scince,social=map(int,input().split()[:6])
    std_total_marks= telugu+english+hindi+maths+scince+social
    stu_percen= (total_marks/600)*100
    # store all values in list
    names.append(name)
    marks.append([telugu,english,hindi,maths,scince,social])
    class_marks.append(total_marks)
    percentage.append(std_percen)
# print the topper detilas
print("topper in the class is")
top_marks=max(class_marks)
toppers_pos= []
for i in range(n):
    if class_marks[i] == top_marks:
        toppers_pos.append(i)
#print the topper details
    for i in range(len(topper_pos)):
        print("Name of the student is:",name[i])
print("marks opf the student is:",marks[i])
#each student marks
for i in range(n):
            print("Name of the student is:",names[i],"Marks is:",marks[i])
# Out:
# welcome to the who is topper
# enter the number of students inthe class:  2
# enter the all student marks
# enter the roll number1 student marks
# enter the student name: ganesh
# enter the Telugu,English,Hindi,Maths,Scince,Social marks, as per the order
#  5
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 15
#      13 name= input("enter the student name:")
#      14 print("enter the Telugu,English,Hindi,Maths,Scince,Social marks, as per the order")
# ---> 15 telugu,english,hindi,maths,scince,social=map(int,input().split()[:6])
#      16 std_total_marks= telugu+english+hindi+maths+scince+social
#      17 stu_percen= (total_marks/600)*100
#
# ValueError: not enough values to unpack (expected 6, got 1)
