# %%
#nested list element access
lst=[1,2,3,4,[10,30,50,['a','b','c',]],29,1,3]
print(lst[4])
print(lst[4][1])
print(lst[4][3][2])
# Out:
# [10, 30, 50, ['a', 'b', 'c']]
# 30
# c

# %%
# read list of number and if number is even and 0.5 and if number is odd add 1
lst=[1,2,3,4,5]
res=[2,2.5,4,4.5,6]
lst=list(map(int,input().split()))
for i in  range (0,len(ist)):
    if lst[i]%2:
        lst[i]=lst[i]+1
else:
    lst[i]+=0.5
    print(lst)
# Out:
#  1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 5
#       3 res=[2,2.5,4,4.5,6]
#       4 lst=list(map(int,input().split()))
# ----> 5 for i in  range (0,len(ist)):
#       6     if lst[i]%2:
#       7         lst[i]=lst[i]+1
#
# NameError: name 'ist' is not defined

# %%
def sum(a,b):
    total=a+b
    return total

a=int(input())
b=int(input())
result=sum(a,b)
print(result)
# Out:
#  10
#  20
# 30

# %%
def sum(a,b,c):
    total=a+b+c
    return total

a=int(input())
b=int(input())
c=int(input())
result=sum(a,b,c)
print(result)
# Out:
#  20
#  30
#  50
# 100

# %%
def sum(a,b,c,d):
    total=a+b+c+d
    return total

a=int(input())
b=int(input())
c=int(input())
d=int(input())
result=sum(a,b,c,d)
print(result)
# Out:
#  10
#  5
#  25
#  14
# 54
